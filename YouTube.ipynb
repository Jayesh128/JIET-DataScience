# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image
from IPython.core.display import HTML 
sbn.set_style("whitegrid");
import warnings
warnings.filterwarnings('ignore')

# %%
train=pd.read_csv("data/INvideos.csv")
train.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc      17.14.11
# 1  zUZ1z7FwLc8      17.14.11
# 2  10L1hZ9qa58      17.14.11
# 3  N1vE8iiEg64      17.14.11
# 4  kJzGH0PVQHQ      17.14.11
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...          HJ NEWS
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 3                     Eruma Saani | Tamil vs English      Eruma Saani
# 4  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
#
#    category_id              publish_time  \
# 0            1  2017-11-12T12:20:39.000Z
# 1           25  2017-11-13T05:43:56.000Z
# 2           24  2017-11-12T15:48:08.000Z
# 3           23  2017-11-12T07:08:48.000Z
# 4           24  2017-11-13T01:14:16.000Z
#
#                                                 tags    views  likes  \
# ...

# %%
data=train.copy()

data=data[data['likes']==900]
plt.figure(figsize=(15,10))
plt.title("views on average youtube video",fontsize=19)
sns.distplot(data['views'])
plt.show()

# %%
sns.jointplot(x="category_id",y="views",data=train,height=10,ratio=3,color='blue')
plt.show()

# %%
sns.jointplot(x="likes",y="views",data=train,height=10,ratio=3,color='blue')
plt.show()

# %%
sns.jointplot(x="comment_count",y="likes",data=train,height=10,ratio=3,color='blue')
plt.show()

# %%
data=train.copy()

data=data[data['dislikes']==900]
plt.figure(figsize=(15,10))
plt.title("views on average youtube video",fontsize=19)
sns.distplot(data['views'])
plt.show()

# %%
data.channel_title.unique()
# Out:
# array(['Love Rudrakash', 'Jordindian', '9Roses Media', 'Infinite view',
#        'TAMIL MEDIA', 'News Tak', 'Flowers Comedy', 'Technical Guruji'],
#       dtype=object)
